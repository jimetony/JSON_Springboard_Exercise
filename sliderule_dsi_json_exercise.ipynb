# %% [markdown]
# # JSON examples and exercise
# ****
# + get familiar with packages for dealing with JSON
# + study examples with JSON strings and files
# + work on exercise to be completed and submitted
# ****
# + reference: http://pandas.pydata.org/pandas-docs/stable/io.html#io-json-reader
# ****

# %%
import pandas as pd

# %% [markdown]
# ## imports for Python, Pandas

# %%
import json
from pandas.io.json import json_normalize

# %% [markdown]
# ## JSON example, with string
#
# + demonstrates creation of normalized dataframes (tables) from nested json string
# + source: http://pandas.pydata.org/pandas-docs/stable/io.html#normalization

# %%
# define json string
data = [{'state': 'Florida', 
         'shortname': 'FL',
         'info': {'governor': 'Rick Scott'},
         'counties': [{'name': 'Dade', 'population': 12345},
                      {'name': 'Broward', 'population': 40000},
                      {'name': 'Palm Beach', 'population': 60000}]},
        {'state': 'Ohio',
         'shortname': 'OH',
         'info': {'governor': 'John Kasich'},
         'counties': [{'name': 'Summit', 'population': 1234},
                      {'name': 'Cuyahoga', 'population': 1337}]}]

# %%
# use normalization to create tables from nested element
json_normalize(data, 'counties')
# Out:
#          name  population
# 0        Dade       12345
# 1     Broward       40000
# 2  Palm Beach       60000
# 3      Summit        1234
# 4    Cuyahoga        1337

# %%
# further populate tables created from nested element
json_normalize(data, 'counties', ['state', 'shortname', ['info', 'governor']])
# Out:
#          name  population    state shortname info.governor
# 0        Dade       12345  Florida        FL    Rick Scott
# 1     Broward       40000  Florida        FL    Rick Scott
# 2  Palm Beach       60000  Florida        FL    Rick Scott
# 3      Summit        1234     Ohio        OH   John Kasich
# 4    Cuyahoga        1337     Ohio        OH   John Kasich

# %% [markdown]
# ****
# ## JSON example, with file
#
# + demonstrates reading in a json file as a string and as a table
# + uses small sample file containing data about projects funded by the World Bank

# %%
# load json as string
json.load((open('data/world_bank_projects_less.json')))
# Out:
# [{'_id': {'$oid': '52b213b38594d8a2be17c780'},
#   'approvalfy': 1999,
#   'board_approval_month': 'November',
#   'boardapprovaldate': '2013-11-12T00:00:00Z',
#   'borrower': 'FEDERAL DEMOCRATIC REPUBLIC OF ETHIOPIA',
#   'closingdate': '2018-07-07T00:00:00Z',
#   'country_namecode': 'Federal Democratic Republic of Ethiopia!$!ET',
#   'countrycode': 'ET',
#   'countryname': 'Federal Democratic Republic of Ethiopia',
#   'countryshortname': 'Ethiopia',
#   'docty': 'Project Information Document,Indigenous Peoples Plan,Project Information Document',
#   'envassesmentcategorycode': 'C',
#   'grantamt': 0,
#   'ibrdcommamt': 0,
#   'id': 'P129828',
#   'idacommamt': 130000000,
#   'impagency': 'MINISTRY OF EDUCATION',
#   'lendinginstr': 'Investment Project Financing',
#   'lendinginstrtype': 'IN',
#   'lendprojectcost': 550000000,
#   'majorsector_percent': [{'Name': 'Education', 'Percent': 46},
#    {'Name': 'Education', 'Percent': 26},
#    {'Name': 'Public Administration, Law, and Justice', 'Percent': 16},
#    {'Name': 'Education', 'Percent': 12}],
#   'mjsector_namecode': [{'name': 'Education', 'code': 'EX'},
#    {'name': 'Education', 'code': 'EX'},
#    {'name': 'Public Administration, Law, and Justice', 'code': 'BX'},
#    {'name': 'Education', 'code': 'EX'}],
#   'mjtheme': ['Human development'],
#   'mjtheme_namecode': [{'name': 'Human development', 'code': '8'},
#    {'name': '', 'code': '11'}],
#   'mjthemecode': '8,11',
#   'prodline': 'PE',
#   'prodlinetext': 'IBRD/IDA',
#   'productlinetype': 'L',
#   'project_abstract': {'cdata': 'The development objective of the Second Phase of General Education Quality Improvement Project for Ethiopia is to improve learning conditions in primary and secondary schools and strengthen institutions at different levels of educational administration. The project has six components. The first component is curriculum, textbooks, assessment, examinations, and inspection. This component will support improvement of learning conditions in grades KG-12 by providing increased access to teaching and learning materials and through improvements to the curriculum by assessing the strengths and weaknesses of the current curriculum. This component has following four sub-components: (i) curriculum reform and implementation; (ii) teaching and learning materials; (iii) assessment and examinations; and (iv) inspection. The second component is teacher development program (TDP). This component will support improvements in learning conditions in both primary and secondary schools by advancing the quality of teaching in general education through: (a) enhancing the training of pre-service teachers in teacher education institutions; and (b) improving the quality of in-service teacher training. This component has following three sub-components: (i) pre-service teacher training; (ii) in-service teacher training; and (iii) licensing and relicensing of teachers and school leaders. The third component is school improvement plan. This component will support the strengthening of school planning in order to improve learning outcomes, and to partly fund the school improvement plans through school grants. It has following two sub-components: (i) school improvement plan; and (ii) school grants. The fourth component is management and capacity building, including education management information systems (EMIS). This component will support management and capacity building aspect of the project. This component has following three sub-components: (i) capacity building for education planning and management; (ii) capacity building for school planning and management; and (iii) EMIS. The fifth component is improving the quality of learning and teaching in secondary schools and universities through the use of information and communications technology (ICT). It has following five sub-components: (i) national policy and institution for ICT in general education; (ii) national ICT infrastructure improvement plan for general education; (iii) develop an integrated monitoring, evaluation, and learning system specifically for the ICT component; (iv) teacher professional development in the use of ICT; and (v) provision of limited number of e-Braille display readers with the possibility to scale up to all secondary education schools based on the successful implementation and usage of the readers. The sixth component is program coordination, monitoring and evaluation, and communication. It will support institutional strengthening by developing capacities in all aspects of program coordination, monitoring and evaluation; a new sub-component on communications will support information sharing for better management and accountability. It has following three sub-components: (i) program coordination; (ii) monitoring and evaluation (M and E); and (iii) communication.'},
#   'project_name': 'Ethiopia General Education Quality Improvement Project II',
#   'projectdocs': [{'DocTypeDesc': 'Project Information Document (PID),  Vol.',
#     'DocType': 'PID',
#     'EntityID': '090224b081e545fb_1_0',
#     'DocURL': 'http://www-wds.worldbank.org/servlet/WDSServlet?pcont=details&eid=090224b081e545fb_1_0',
#     'DocDate': '28-AUG-2013'},
#    {'DocTypeDesc': 'Indigenous Peoples Plan (IP),  Vol.1 of 1',
#     'DocType': 'IP',
#     'EntityID': '000442464_20130920111729',
#     'DocURL': 'http://www-wds.worldbank.org/servlet/WDSServlet?pcont=details&eid=000442464_20130920111729',
#     'DocDate': '01-JUL-2013'},
#    {'DocTypeDesc': 'Project Information Document (PID),  Vol.',
#     'DocType': 'PID',
#     'EntityID': '090224b0817b19e2_1_0',
#     'DocURL': 'http://www-wds.worldbank.org/servlet/WDSServlet?pcont=details&eid=090224b0817b19e2_1_0',
#     'DocDate': '22-NOV-2012'}],
#   'projectfinancialtype': 'IDA',
#   'projectstatusdisplay': 'Active',
#   'regionname': 'Africa',
#   'sector': [{'Name': 'Primary education'},
#    {'Name': 'Secondary education'},
#    {'Name': 'Public administration- Other social services'},
#    {'Name': 'Tertiary education'}],
#   'sector1': {'Name': 'Primary education', 'Percent': 46},
#   'sector2': {'Name': 'Secondary education', 'Percent': 26},
#   'sector3': {'Name': 'Public administration- Other social services',
#    'Percent': 16},
#   'sector4': {'Name': 'Tertiary education', 'Percent': 12},
#   'sector_namecode': [{'name': 'Primary education', 'code': 'EP'},
#    {'name': 'Secondary education', 'code': 'ES'},
#    {'name': 'Public administration- Other social services', 'code': 'BS'},
#    {'name': 'Tertiary education', 'code': 'ET'}],
#   'sectorcode': 'ET,BS,ES,EP',
#   'source': 'IBRD',
#   'status': 'Active',
#   'supplementprojectflg': 'N',
#   'theme1': {'Name': 'Education for all', 'Percent': 100},
#   'theme_namecode': [{'name': 'Education for all', 'code': '65'}],
#   'themecode': '65',
#   'totalamt': 130000000,
#   'totalcommamt': 130000000,
#   'url': 'http://www.worldbank.org/projects/P129828/ethiopia-general-education-quality-improvement-project-ii?lang=en'},
#  {'_id': {'$oid': '52b213b38594d8a2be17c781'},
#   'approvalfy': 2015,
#   'board_approval_month': 'November',
#   'boardapprovaldate': '2013-11-04T00:00:00Z',
#   'borrower': 'GOVERNMENT OF TUNISIA',
#   'country_namecode': 'Republic of Tunisia!$!TN',
#   'countrycode': 'TN',
#   'countryname': 'Republic of Tunisia',
#   'countryshortname': 'Tunisia',
#   'docty': 'Project Information Document,Integrated Safeguards Data Sheet,Integrated Safeguards Data Sheet,Project Information Document,Integrated Safeguards Data Sheet,Project Information Document',
#   'envassesmentcategorycode': 'C',
#   'grantamt': 4700000,
#   'ibrdcommamt': 0,
#   'id': 'P144674',
#   'idacommamt': 0,
#   'impagency': 'MINISTRY OF FINANCE',
#   'lendinginstr': 'Specific Investment Loan',
#   'lendinginstrtype': 'IN',
#   'lendprojectcost': 5700000,
#   'majorsector_percent': [{'Name': 'Public Administration, Law, and Justice',
#     'Percent': 70},
#    {'Name': 'Public Administration, Law, and Justice', 'Percent': 30}],
#   'mjsector_namecode': [{'name': 'Public Administration, Law, and Justice',
#     'code': 'BX'},
#    {'name': 'Public Administration, Law, and Justice', 'code': 'BX'}],
#   'mjtheme': ['Economic management', 'Social protection and risk management'],
#   'mjtheme_namecode': [{'name': 'Economic management', 'code': '1'},
#    {'name': 'Social protection and risk management', 'code': '6'}],
#   'mjthemecode': '1,6',
#   'prodline': 'RE',
#   'prodlinetext': 'Recipient Executed Activities',
#   'productlinetype': 'L',
#   'project_name': 'TN: DTF Social Protection Reforms Support',
#   'projectdocs': [{'DocTypeDesc': 'Project Information Document (PID),  Vol.1 of 1',
#     'DocType': 'PID',
#     'EntityID': '000333037_20131024115616',
#     'DocURL': 'http://www-wds.worldbank.org/servlet/WDSServlet?pcont=details&eid=000333037_20131024115616',
#     'DocDate': '29-MAR-2013'},
#    {'DocTypeDesc': 'Integrated Safeguards Data Sheet (ISDS),  Vol.1 of 1',
#     'DocType': 'ISDS',
#     'EntityID': '000356161_20131024151611',
#     'DocURL': 'http://www-wds.worldbank.org/servlet/WDSServlet?pcont=details&eid=000356161_20131024151611',
#     'DocDate': '29-MAR-2013'},
#    {'DocTypeDesc': 'Integrated Safeguards Data Sheet (ISDS),  Vol.1 of 1',
#     'DocType': 'ISDS',
#     'EntityID': '000442464_20131031112136',
#     'DocURL': 'http://www-wds.worldbank.org/servlet/WDSServlet?pcont=details&eid=000442464_20131031112136',
#     'DocDate': '29-MAR-2013'},
#    {'DocTypeDesc': 'Project Information Document (PID),  Vol.1 of 1',
#     'DocType': 'PID',
#     'EntityID': '000333037_20131031105716',
#     'DocURL': 'http://www-wds.worldbank.org/servlet/WDSServlet?pcont=details&eid=000333037_20131031105716',
#     'DocDate': '29-MAR-2013'},
#    {'DocTypeDesc': 'Integrated Safeguards Data Sheet (ISDS),  Vol.1 of 1',
#     'DocType': 'ISDS',
#     'EntityID': '000356161_20130305113209',
#     'DocURL': 'http://www-wds.worldbank.org/servlet/WDSServlet?pcont=details&eid=000356161_20130305113209',
#     'DocDate': '16-JAN-2013'},
#    {'DocTypeDesc': 'Project Information Document (PID),  Vol.1 of 1',
#     'DocType': 'PID',
#     'EntityID': '000356161_20130305113716',
#     'DocURL': 'http://www-wds.worldbank.org/servlet/WDSServlet?pcont=details&eid=000356161_20130305113716',
#     'DocDate': '16-JAN-2013'}],
#   'projectfinancialtype': 'OTHER',
#   'projectstatusdisplay': 'Active',
#   'regionname': 'Middle East and North Africa',
#   'sector': [{'Name': 'Public administration- Other social services'},
#    {'Name': 'General public administration sector'}],
#   'sector1': {'Name': 'Public administration- Other social services',
#    'Percent': 70},
#   'sector2': {'Name': 'General public administration sector', 'Percent': 30},
#   'sector_namecode': [{'name': 'Public administration- Other social services',
#     'code': 'BS'},
#    {'name': 'General public administration sector', 'code': 'BZ'}],
#   'sectorcode': 'BZ,BS',
#   'source': 'IBRD',
#   'status': 'Active',
#   'supplementprojectflg': 'N',
#   'theme1': {'Name': 'Other economic management', 'Percent': 30},
#   'theme_namecode': [{'name': 'Other economic management', 'code': '24'},
#    {'name': 'Social safety nets', 'code': '54'}],
#   'themecode': '54,24',
#   'totalamt': 0,
#   'totalcommamt': 4700000,
#   'url': 'http://www.worldbank.org/projects/P144674?lang=en'}]

# %%
# load as Pandas dataframe
sample_json_df = pd.read_json('data/world_bank_projects_less.json')
sample_json_df
# Out:
#                                     _id  approvalfy board_approval_month  \
# 0  {'$oid': '52b213b38594d8a2be17c780'}        1999             November
# 1  {'$oid': '52b213b38594d8a2be17c781'}        2015             November
#
#       boardapprovaldate                                 borrower  \
# 0  2013-11-12T00:00:00Z  FEDERAL DEMOCRATIC REPUBLIC OF ETHIOPIA
# 1  2013-11-04T00:00:00Z                    GOVERNMENT OF TUNISIA
#
#             closingdate                              country_namecode  \
# 0  2018-07-07T00:00:00Z  Federal Democratic Republic of Ethiopia!$!ET
# 1                   NaN                      Republic of Tunisia!$!TN
#
#   countrycode                              countryname countryshortname  ...  \
# 0          ET  Federal Democratic Republic of Ethiopia         Ethiopia  ...
# 1          TN                      Republic of Tunisia          Tunisia  ...
#
#     sectorcode source  status  supplementprojectflg  \
# 0  ET,BS,ES,EP   IBRD  Active                     N
# 1        BZ,BS   IBRD  Active                     N
#
#                                               theme1  \
# 0      {'Name': 'Education for all', 'Percent': 100}
# 1  {'Name': 'Other economic management', 'Percent...
#
#                                       theme_namecode themecode   totalamt  \
# 0      [{'name': 'Education for all', 'code': '65'}]        65  130000000
# 1  [{'name': 'Other economic management', 'code':...     54,24          0
#
#   totalcommamt                                                url
# 0    130000000  http://www.worldbank.org/projects/P129828/ethi...
# 1      4700000  http://www.worldbank.org/projects/P144674?lang=en
#
# [2 rows x 50 columns]

# %% [markdown]
# ****
# ## JSON exercise
#
# Using data in file 'data/world_bank_projects.json' and the techniques demonstrated above,
# 1. Find the 10 countries with most projects
# 2. Find the top 10 major project themes (using column 'mjtheme_namecode')
# 3. In 2. above you will notice that some entries have only the code and the name is missing. Create a dataframe with the missing names filled in.

# %%
import pandas as pd

# %%
import json
from pandas.io.json import json_normalize

# %%
#load json as a string
wbank_json = json.load((open('data/world_bank_projects.json')))

# %%
print(type(wbank_json))
# Out:
# <class 'list'>

# %%
#since list, lets see what type is inside
print(type(wbank_json[0]))
# Out:
# <class 'dict'>

# %%
#access dict to see keys
print(wbank_json[0].keys())
# Out:
# dict_keys(['sector', 'supplementprojectflg', 'projectfinancialtype', 'prodline', 'mjtheme', 'idacommamt', 'impagency', 'project_name', 'mjthemecode', 'closingdate', 'totalcommamt', 'id', 'mjsector_namecode', 'docty', 'sector1', 'lendinginstr', 'countrycode', 'sector2', 'totalamt', 'mjtheme_namecode', 'boardapprovaldate', 'countryshortname', 'sector4', 'prodlinetext', 'productlinetype', 'regionname', 'status', 'country_namecode', 'envassesmentcategorycode', 'project_abstract', 'approvalfy', 'projectdocs', 'lendprojectcost', 'lendinginstrtype', 'theme1', 'grantamt', 'themecode', 'borrower', 'sectorcode', 'sector3', 'majorsector_percent', 'board_approval_month', 'theme_namecode', 'countryname', 'url', 'source', 'projectstatusdisplay', 'ibrdcommamt', 'sector_namecode', '_id'])

# %%
#normalization to create a table with values and view first 10 values
print(json_normalize(wbank_json).head(10))
# Out:
#                                               sector supplementprojectflg  \
# 0  [{'Name': 'Primary education'}, {'Name': 'Seco...                    N
# 1  [{'Name': 'Public administration- Other social...                    N
# 2  [{'Name': 'Rural and Inter-Urban Roads and Hig...                    Y
# 3                [{'Name': 'Other social services'}]                    N
# 4  [{'Name': 'General industry and trade sector'}...                    N
# 5                [{'Name': 'Other social services'}]                    Y
# 6  [{'Name': 'Rural and Inter-Urban Roads and Hig...                    N
# 7               [{'Name': 'Other Renewable Energy'}]                    N
# 8  [{'Name': 'Rural and Inter-Urban Roads and Hig...                    N
# 9  [{'Name': 'General public administration secto...                    N
#
#   projectfinancialtype prodline  \
# 0                  IDA       PE
# 1                OTHER       RE
# 2                  IDA       PE
# 3                OTHER       RE
# 4                  IDA       PE
# 5                  IDA       PE
# 6                 IBRD       PE
# 7                OTHER       GE
# 8                  IDA       PE
# 9                 IBRD       PE
#
#                                              mjtheme  idacommamt  \
# 0                                [Human development]   130000000
# 1  [Economic management, Social protection and ri...           0
# 2  [Trade and integration, Public sector governan...     6060000
# 3  [Social dev/gender/inclusion, Social dev/gende...           0
# 4  [Trade and integration, Financial and private ...    13100000
# 5            [Social protection and risk management]    10000000
# 6  [Public sector governance, Financial and priva...           0
# 7     [Environment and natural resources management]           0
# 8                                [Rural development]   160000000
# 9  [Public sector governance, Public sector gover...           0
#
#                                   impagency  \
# 0                     MINISTRY OF EDUCATION
# 1                       MINISTRY OF FINANCE
# 2  MINISTRY OF TRANSPORT AND COMMUNICATIONS
# 3  LABOR INTENSIVE PUBLIC WORKS PROJECT PMU
# 4            MINISTRY OF TRADE AND INDUSTRY
# 5                                       NaN
# 6   MINISTRY OF ROAD TRANSPORT AND HIGHWAYS
# 7            NATIONAL ENERGY ADMINISTRATION
# 8        PUBLIC WORKS DEPARTMANT, RAJASTHAN
# 9                       MINISTRY OF FINANCE
#
#                                         project_name mjthemecode  \
# 0  Ethiopia General Education Quality Improvement...        8,11
# 1          TN: DTF Social Protection Reforms Support         1,6
# 2  Tuvalu Aviation Investment Project - Additiona...    5,2,11,6
# 3   Gov't and Civil Society Organization Partnership         7,7
# 4  Second Private Sector Competitiveness and Econ...         5,4
# 5  Additional Financing for Cash Transfers for Or...         6,6
# 6  National Highways Interconnectivity Improvemen...         2,4
# 7   China Renewable Energy Scale-Up Program Phase II        11,8
# 8        Rajasthan Road Sector Modernization Project        10,7
# 9             MA Accountability and Transparency DPL       2,2,2
#
#             closingdate  ...  sector2.Percent  \
# 0  2018-07-07T00:00:00Z  ...             26.0
# 1                   NaN  ...             30.0
# 2                   NaN  ...              NaN
# 3                   NaN  ...              NaN
# 4  2019-04-30T00:00:00Z  ...             40.0
# 5                   NaN  ...              NaN
# 6  2019-06-30T00:00:00Z  ...              NaN
# 7                   NaN  ...              NaN
# 8  2018-12-31T00:00:00Z  ...              NaN
# 9  2014-12-31T00:00:00Z  ...             33.0
#
#                            sector2.Name sector4.Percent        sector4.Name  \
# 0                   Secondary education            12.0  Tertiary education
# 1  General public administration sector             NaN                 NaN
# 2                                   NaN             NaN                 NaN
# 3                                   NaN             NaN                 NaN
# 4                        Other industry             NaN                 NaN
# 5                                   NaN             NaN                 NaN
# 6                                   NaN             NaN                 NaN
# 7                                   NaN             NaN                 NaN
# 8                                   NaN             NaN                 NaN
# 9     Central government administration             NaN                 NaN
#
#                               project_abstract.cdata theme1.Percent  \
# 0  The development objective of the Second Phase ...            100
# 1                                                NaN             30
# 2                                                NaN             46
# 3                                                NaN             50
# 4  The development objective of the Second Privat...             30
# 5                                                NaN            100
# 6  The development objective of the project is to...             20
# 7  The development objective of the Second Phase ...            100
# 8  The development objective of the Rajasthan Roa...             87
# 9  The objective of this First Transparency and A...             33
#
#                                theme1.Name sector3.Percent  \
# 0                        Education for all            16.0
# 1                Other economic management             NaN
# 2                     Regional integration             NaN
# 3       Participation and civic engagement             NaN
# 4   Export development and competitiveness            10.0
# 5                       Social safety nets             NaN
# 6  Administrative and civil service reform             NaN
# 7                           Climate change             NaN
# 8                  Other rural development             NaN
# 9     Other accountability/anti-corruption            33.0
#
#                                         sector3.Name                  _id.$oid
# 0       Public administration- Other social services  52b213b38594d8a2be17c780
# 1                                                NaN  52b213b38594d8a2be17c781
# 2                                                NaN  52b213b38594d8a2be17c782
# 3                                                NaN  52b213b38594d8a2be17c783
# 4                                        SME Finance  52b213b38594d8a2be17c784
# 5                                                NaN  52b213b38594d8a2be17c785
# 6                                                NaN  52b213b38594d8a2be17c786
# 7                                                NaN  52b213b38594d8a2be17c787
# 8                                                NaN  52b213b38594d8a2be17c788
# 9  Public administration- Information and communi...  52b213b38594d8a2be17c789
#
# [10 rows x 55 columns]

# %%
#convert to Data Frame
wbank_df = pd.read_json('data/world_bank_projects.json')

# %%
#saw countryname, countrycode, country_namecode, and countryshortname in the key values
#will count how many of each countryshortname
wbank_countryshortname_count = wbank_df['countryshortname'].value_counts()

# %%
# 1. Find the 10 countries with most projects
#for top ten we can use head() so
print("--> 1. Top 10 Countries with the most projects are:")
print(wbank_countryshortname_count.head(10))
# Out:
# --> 1. Top 10 Countries with the most projects are:
# China                 19
# Indonesia             19
# Vietnam               17
# India                 16
# Yemen, Republic of    13
# Nepal                 12
# Bangladesh            12
# Morocco               12
# Mozambique            11
# Africa                11
# Name: countryshortname, dtype: int64

# %%
# create a series of lists of just the column mjtheme_namecode
wbank_mjtheme = wbank_df['mjtheme_namecode']
#see what each element has
print(wbank_mjtheme)
#print(wbank_mjtheme[0][0]['name'])
#-- Human development
# Out:
# 0      [{'code': '8', 'name': 'Human development'}, {...
# 1      [{'code': '1', 'name': 'Economic management'},...
# 2      [{'code': '5', 'name': 'Trade and integration'...
# 3      [{'code': '7', 'name': 'Social dev/gender/incl...
# 4      [{'code': '5', 'name': 'Trade and integration'...
#                              ...
# 495    [{'code': '4', 'name': 'Financial and private ...
# 496    [{'code': '8', 'name': 'Human development'}, {...
# 497    [{'code': '10', 'name': 'Rural development'}, ...
# 498    [{'code': '10', 'name': 'Rural development'}, ...
# 499    [{'code': '9', 'name': 'Urban development'}, {...
# Name: mjtheme_namecode, Length: 500, dtype: object

# %%
#create a list of all code and names using for loop

all = []
for value in wbank_mjtheme:
    for i in value:
        all.append(i)
# make the list into a dataframe to be able to use value_counts()
new_mjtheme = pd.DataFrame(all)

project_themes_count = new_mjtheme['name'].value_counts()

# %%
# 2. Find the top 10 major project themes (using column 'mjtheme_namecode')
print("--> 2. Top 10 major project themes are: ")
print(project_themes_count.head(10))
# Out:
# --> 2. Top 10 major project themes are:
# Environment and natural resources management    223
# Rural development                               202
# Human development                               197
# Public sector governance                        184
# Social protection and risk management           158
# Financial and private sector development        130
#                                                 122
# Social dev/gender/inclusion                     119
# Trade and integration                            72
# Urban development                                47
# Name: name, dtype: int64

# %%
print(new_mjtheme)
# Out:
#      code                                      name
# 0       8                         Human development
# 1      11
# 2       1                       Economic management
# 3       6     Social protection and risk management
# 4       5                     Trade and integration
# ...   ...                                       ...
# 1494   10                         Rural development
# 1495    9                         Urban development
# 1496    8                         Human development
# 1497    5                     Trade and integration
# 1498    4  Financial and private sector development
#
# [1499 rows x 2 columns]

# %%
#create a dict for each code to match a name
code_names = {}

for row in new_mjtheme.itertuples():
    print(row)
    if row[2] != '':
        code_names[row[1]] = row[2]
        
print(code_names)
# Out:
# Pandas(Index=0, code='8', name='Human development')
# Pandas(Index=1, code='11', name='')
# Pandas(Index=2, code='1', name='Economic management')
# Pandas(Index=3, code='6', name='Social protection and risk management')
# Pandas(Index=4, code='5', name='Trade and integration')
# Pandas(Index=5, code='2', name='Public sector governance')
# Pandas(Index=6, code='11', name='Environment and natural resources management')
# Pandas(Index=7, code='6', name='Social protection and risk management')
# Pandas(Index=8, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=9, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=10, code='5', name='Trade and integration')
# Pandas(Index=11, code='4', name='Financial and private sector development')
# Pandas(Index=12, code='6', name='Social protection and risk management')
# Pandas(Index=13, code='6', name='')
# Pandas(Index=14, code='2', name='Public sector governance')
# Pandas(Index=15, code='4', name='Financial and private sector development')
# Pandas(Index=16, code='11', name='Environment and natural resources management')
# Pandas(Index=17, code='8', name='')
# Pandas(Index=18, code='10', name='Rural development')
# Pandas(Index=19, code='7', name='')
# Pandas(Index=20, code='2', name='Public sector governance')
# Pandas(Index=21, code='2', name='Public sector governance')
# Pandas(Index=22, code='2', name='Public sector governance')
# Pandas(Index=23, code='10', name='Rural development')
# Pandas(Index=24, code='2', name='')
# Pandas(Index=25, code='10', name='Rural development')
# Pandas(Index=26, code='6', name='Social protection and risk management')
# Pandas(Index=27, code='6', name='Social protection and risk management')
# Pandas(Index=28, code='11', name='Environment and natural resources management')
# Pandas(Index=29, code='4', name='')
# Pandas(Index=30, code='5', name='Trade and integration')
# Pandas(Index=31, code='11', name='Environment and natural resources management')
# Pandas(Index=32, code='10', name='Rural development')
# Pandas(Index=33, code='6', name='Social protection and risk management')
# Pandas(Index=34, code='6', name='Social protection and risk management')
# Pandas(Index=35, code='6', name='Social protection and risk management')
# Pandas(Index=36, code='10', name='Rural development')
# Pandas(Index=37, code='11', name='Environment and natural resources management')
# Pandas(Index=38, code='5', name='Trade and integration')
# Pandas(Index=39, code='10', name='Rural development')
# Pandas(Index=40, code='2', name='')
# Pandas(Index=41, code='8', name='Human development')
# Pandas(Index=42, code='7', name='')
# Pandas(Index=43, code='8', name='Human development')
# Pandas(Index=44, code='8', name='Human development')
# Pandas(Index=45, code='2', name='Public sector governance')
# Pandas(Index=46, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=47, code='8', name='Human development')
# Pandas(Index=48, code='2', name='Public sector governance')
# Pandas(Index=49, code='2', name='Public sector governance')
# Pandas(Index=50, code='2', name='Public sector governance')
# Pandas(Index=51, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=52, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=53, code='9', name='Urban development')
# Pandas(Index=54, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=55, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=56, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=57, code='8', name='Human development')
# Pandas(Index=58, code='8', name='Human development')
# Pandas(Index=59, code='10', name='Rural development')
# Pandas(Index=60, code='10', name='Rural development')
# Pandas(Index=61, code='10', name='Rural development')
# Pandas(Index=62, code='6', name='Social protection and risk management')
# Pandas(Index=63, code='11', name='Environment and natural resources management')
# Pandas(Index=64, code='11', name='Environment and natural resources management')
# Pandas(Index=65, code='11', name='Environment and natural resources management')
# Pandas(Index=66, code='4', name='Financial and private sector development')
# Pandas(Index=67, code='5', name='Trade and integration')
# Pandas(Index=68, code='2', name='Public sector governance')
# Pandas(Index=69, code='8', name='Human development')
# Pandas(Index=70, code='11', name='Environment and natural resources management')
# Pandas(Index=71, code='2', name='Public sector governance')
# Pandas(Index=72, code='5', name='Trade and integration')
# Pandas(Index=73, code='6', name='Social protection and risk management')
# Pandas(Index=74, code='10', name='Rural development')
# Pandas(Index=75, code='10', name='Rural development')
# Pandas(Index=76, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=77, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=78, code='11', name='Environment and natural resources management')
# Pandas(Index=79, code='8', name='Human development')
# Pandas(Index=80, code='4', name='')
# Pandas(Index=81, code='11', name='Environment and natural resources management')
# Pandas(Index=82, code='11', name='Environment and natural resources management')
# Pandas(Index=83, code='11', name='Environment and natural resources management')
# Pandas(Index=84, code='11', name='Environment and natural resources management')
# Pandas(Index=85, code='11', name='Environment and natural resources management')
# Pandas(Index=86, code='4', name='Financial and private sector development')
# Pandas(Index=87, code='6', name='Social protection and risk management')
# Pandas(Index=88, code='1', name='Economic management')
# Pandas(Index=89, code='4', name='Financial and private sector development')
# Pandas(Index=90, code='2', name='Public sector governance')
# Pandas(Index=91, code='8', name='Human development')
# Pandas(Index=92, code='5', name='Trade and integration')
# Pandas(Index=93, code='5', name='Trade and integration')
# Pandas(Index=94, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=95, code='10', name='Rural development')
# Pandas(Index=96, code='4', name='Financial and private sector development')
# Pandas(Index=97, code='10', name='Rural development')
# Pandas(Index=98, code='11', name='')
# Pandas(Index=99, code='6', name='Social protection and risk management')
# Pandas(Index=100, code='7', name='')
# Pandas(Index=101, code='11', name='Environment and natural resources management')
# Pandas(Index=102, code='11', name='Environment and natural resources management')
# Pandas(Index=103, code='6', name='Social protection and risk management')
# Pandas(Index=104, code='11', name='Environment and natural resources management')
# Pandas(Index=105, code='11', name='Environment and natural resources management')
# Pandas(Index=106, code='2', name='Public sector governance')
# Pandas(Index=107, code='4', name='')
# Pandas(Index=108, code='11', name='Environment and natural resources management')
# Pandas(Index=109, code='6', name='Social protection and risk management')
# Pandas(Index=110, code='11', name='Environment and natural resources management')
# Pandas(Index=111, code='11', name='Environment and natural resources management')
# Pandas(Index=112, code='4', name='Financial and private sector development')
# Pandas(Index=113, code='8', name='Human development')
# Pandas(Index=114, code='2', name='Public sector governance')
# Pandas(Index=115, code='2', name='Public sector governance')
# Pandas(Index=116, code='2', name='Public sector governance')
# Pandas(Index=117, code='8', name='')
# Pandas(Index=118, code='11', name='Environment and natural resources management')
# Pandas(Index=119, code='7', name='')
# Pandas(Index=120, code='8', name='Human development')
# Pandas(Index=121, code='10', name='')
# Pandas(Index=122, code='2', name='Public sector governance')
# Pandas(Index=123, code='10', name='Rural development')
# Pandas(Index=124, code='4', name='Financial and private sector development')
# Pandas(Index=125, code='4', name='Financial and private sector development')
# Pandas(Index=126, code='11', name='Environment and natural resources management')
# Pandas(Index=127, code='11', name='')
# Pandas(Index=128, code='4', name='Financial and private sector development')
# Pandas(Index=129, code='4', name='Financial and private sector development')
# Pandas(Index=130, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=131, code='6', name='Social protection and risk management')
# Pandas(Index=132, code='2', name='Public sector governance')
# Pandas(Index=133, code='11', name='Environment and natural resources management')
# Pandas(Index=134, code='4', name='')
# Pandas(Index=135, code='11', name='Environment and natural resources management')
# Pandas(Index=136, code='11', name='Environment and natural resources management')
# Pandas(Index=137, code='11', name='Environment and natural resources management')
# Pandas(Index=138, code='11', name='Environment and natural resources management')
# Pandas(Index=139, code='11', name='Environment and natural resources management')
# Pandas(Index=140, code='11', name='Environment and natural resources management')
# Pandas(Index=141, code='11', name='Environment and natural resources management')
# Pandas(Index=142, code='10', name='Rural development')
# Pandas(Index=143, code='2', name='Public sector governance')
# Pandas(Index=144, code='5', name='Trade and integration')
# Pandas(Index=145, code='2', name='Public sector governance')
# Pandas(Index=146, code='8', name='Human development')
# Pandas(Index=147, code='8', name='Human development')
# Pandas(Index=148, code='8', name='Human development')
# Pandas(Index=149, code='11', name='Environment and natural resources management')
# Pandas(Index=150, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=151, code='11', name='Environment and natural resources management')
# Pandas(Index=152, code='11', name='Environment and natural resources management')
# Pandas(Index=153, code='11', name='Environment and natural resources management')
# Pandas(Index=154, code='4', name='Financial and private sector development')
# Pandas(Index=155, code='4', name='Financial and private sector development')
# Pandas(Index=156, code='11', name='Environment and natural resources management')
# Pandas(Index=157, code='2', name='Public sector governance')
# Pandas(Index=158, code='10', name='Rural development')
# Pandas(Index=159, code='10', name='Rural development')
# Pandas(Index=160, code='11', name='Environment and natural resources management')
# Pandas(Index=161, code='11', name='Environment and natural resources management')
# Pandas(Index=162, code='2', name='Public sector governance')
# Pandas(Index=163, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=164, code='2', name='Public sector governance')
# Pandas(Index=165, code='10', name='')
# Pandas(Index=166, code='5', name='Trade and integration')
# Pandas(Index=167, code='6', name='Social protection and risk management')
# Pandas(Index=168, code='10', name='Rural development')
# Pandas(Index=169, code='10', name='Rural development')
# Pandas(Index=170, code='11', name='Environment and natural resources management')
# Pandas(Index=171, code='4', name='')
# Pandas(Index=172, code='6', name='Social protection and risk management')
# Pandas(Index=173, code='2', name='')
# Pandas(Index=174, code='6', name='Social protection and risk management')
# Pandas(Index=175, code='1', name='Economic management')
# Pandas(Index=176, code='2', name='Public sector governance')
# Pandas(Index=177, code='11', name='Environment and natural resources management')
# Pandas(Index=178, code='2', name='Public sector governance')
# Pandas(Index=179, code='4', name='Financial and private sector development')
# Pandas(Index=180, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=181, code='10', name='Rural development')
# Pandas(Index=182, code='5', name='Trade and integration')
# Pandas(Index=183, code='9', name='Urban development')
# Pandas(Index=184, code='11', name='Environment and natural resources management')
# Pandas(Index=185, code='7', name='')
# Pandas(Index=186, code='8', name='Human development')
# Pandas(Index=187, code='11', name='')
# Pandas(Index=188, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=189, code='6', name='Social protection and risk management')
# Pandas(Index=190, code='8', name='Human development')
# Pandas(Index=191, code='8', name='Human development')
# Pandas(Index=192, code='8', name='Human development')
# Pandas(Index=193, code='4', name='Financial and private sector development')
# Pandas(Index=194, code='9', name='Urban development')
# Pandas(Index=195, code='10', name='Rural development')
# Pandas(Index=196, code='11', name='Environment and natural resources management')
# Pandas(Index=197, code='4', name='')
# Pandas(Index=198, code='4', name='Financial and private sector development')
# Pandas(Index=199, code='4', name='Financial and private sector development')
# Pandas(Index=200, code='9', name='Urban development')
# Pandas(Index=201, code='5', name='')
# Pandas(Index=202, code='2', name='Public sector governance')
# Pandas(Index=203, code='5', name='Trade and integration')
# Pandas(Index=204, code='1', name='Economic management')
# Pandas(Index=205, code='1', name='Economic management')
# Pandas(Index=206, code='8', name='Human development')
# Pandas(Index=207, code='4', name='Financial and private sector development')
# Pandas(Index=208, code='4', name='Financial and private sector development')
# Pandas(Index=209, code='11', name='Environment and natural resources management')
# Pandas(Index=210, code='11', name='')
# Pandas(Index=211, code='2', name='Public sector governance')
# Pandas(Index=212, code='1', name='')
# Pandas(Index=213, code='6', name='Social protection and risk management')
# Pandas(Index=214, code='6', name='Social protection and risk management')
# Pandas(Index=215, code='6', name='Social protection and risk management')
# Pandas(Index=216, code='2', name='Public sector governance')
# Pandas(Index=217, code='10', name='')
# Pandas(Index=218, code='2', name='Public sector governance')
# Pandas(Index=219, code='4', name='Financial and private sector development')
# Pandas(Index=220, code='1', name='Economic management')
# Pandas(Index=221, code='6', name='Social protection and risk management')
# Pandas(Index=222, code='1', name='Economic management')
# Pandas(Index=223, code='1', name='Economic management')
# Pandas(Index=224, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=225, code='5', name='Trade and integration')
# Pandas(Index=226, code='2', name='Public sector governance')
# Pandas(Index=227, code='2', name='Public sector governance')
# Pandas(Index=228, code='8', name='Human development')
# Pandas(Index=229, code='8', name='Human development')
# Pandas(Index=230, code='4', name='')
# Pandas(Index=231, code='2', name='Public sector governance')
# Pandas(Index=232, code='6', name='')
# Pandas(Index=233, code='11', name='')
# Pandas(Index=234, code='2', name='Public sector governance')
# Pandas(Index=235, code='4', name='')
# Pandas(Index=236, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=237, code='8', name='Human development')
# Pandas(Index=238, code='8', name='Human development')
# Pandas(Index=239, code='8', name='Human development')
# Pandas(Index=240, code='8', name='')
# Pandas(Index=241, code='4', name='Financial and private sector development')
# Pandas(Index=242, code='11', name='')
# Pandas(Index=243, code='11', name='Environment and natural resources management')
# Pandas(Index=244, code='4', name='Financial and private sector development')
# Pandas(Index=245, code='8', name='Human development')
# Pandas(Index=246, code='5', name='Trade and integration')
# Pandas(Index=247, code='4', name='Financial and private sector development')
# Pandas(Index=248, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=249, code='1', name='Economic management')
# Pandas(Index=250, code='6', name='Social protection and risk management')
# Pandas(Index=251, code='4', name='Financial and private sector development')
# Pandas(Index=252, code='3', name='Rule of law')
# Pandas(Index=253, code='4', name='Financial and private sector development')
# Pandas(Index=254, code='4', name='Financial and private sector development')
# Pandas(Index=255, code='10', name='Rural development')
# Pandas(Index=256, code='10', name='Rural development')
# Pandas(Index=257, code='10', name='Rural development')
# Pandas(Index=258, code='10', name='Rural development')
# Pandas(Index=259, code='10', name='Rural development')
# Pandas(Index=260, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=261, code='10', name='Rural development')
# Pandas(Index=262, code='10', name='Rural development')
# Pandas(Index=263, code='5', name='Trade and integration')
# Pandas(Index=264, code='4', name='Financial and private sector development')
# Pandas(Index=265, code='5', name='Trade and integration')
# Pandas(Index=266, code='5', name='Trade and integration')
# Pandas(Index=267, code='5', name='Trade and integration')
# Pandas(Index=268, code='2', name='Public sector governance')
# Pandas(Index=269, code='10', name='Rural development')
# Pandas(Index=270, code='11', name='Environment and natural resources management')
# Pandas(Index=271, code='10', name='Rural development')
# Pandas(Index=272, code='10', name='Rural development')
# Pandas(Index=273, code='10', name='Rural development')
# Pandas(Index=274, code='4', name='Financial and private sector development')
# Pandas(Index=275, code='10', name='')
# Pandas(Index=276, code='2', name='')
# Pandas(Index=277, code='11', name='')
# Pandas(Index=278, code='8', name='Human development')
# Pandas(Index=279, code='8', name='Human development')
# Pandas(Index=280, code='2', name='Public sector governance')
# Pandas(Index=281, code='5', name='Trade and integration')
# Pandas(Index=282, code='6', name='Social protection and risk management')
# Pandas(Index=283, code='11', name='Environment and natural resources management')
# Pandas(Index=284, code='11', name='Environment and natural resources management')
# Pandas(Index=285, code='4', name='Financial and private sector development')
# Pandas(Index=286, code='5', name='Trade and integration')
# Pandas(Index=287, code='11', name='Environment and natural resources management')
# Pandas(Index=288, code='2', name='Public sector governance')
# Pandas(Index=289, code='2', name='Public sector governance')
# Pandas(Index=290, code='2', name='Public sector governance')
# Pandas(Index=291, code='11', name='Environment and natural resources management')
# Pandas(Index=292, code='6', name='Social protection and risk management')
# Pandas(Index=293, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=294, code='11', name='Environment and natural resources management')
# Pandas(Index=295, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=296, code='4', name='Financial and private sector development')
# Pandas(Index=297, code='2', name='')
# Pandas(Index=298, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=299, code='6', name='Social protection and risk management')
# Pandas(Index=300, code='6', name='Social protection and risk management')
# Pandas(Index=301, code='2', name='Public sector governance')
# Pandas(Index=302, code='8', name='Human development')
# Pandas(Index=303, code='10', name='Rural development')
# Pandas(Index=304, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=305, code='8', name='Human development')
# Pandas(Index=306, code='2', name='Public sector governance')
# Pandas(Index=307, code='8', name='Human development')
# Pandas(Index=308, code='6', name='Social protection and risk management')
# Pandas(Index=309, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=310, code='2', name='Public sector governance')
# Pandas(Index=311, code='6', name='Social protection and risk management')
# Pandas(Index=312, code='2', name='Public sector governance')
# Pandas(Index=313, code='4', name='Financial and private sector development')
# Pandas(Index=314, code='10', name='Rural development')
# Pandas(Index=315, code='8', name='Human development')
# Pandas(Index=316, code='4', name='Financial and private sector development')
# Pandas(Index=317, code='5', name='Trade and integration')
# Pandas(Index=318, code='9', name='Urban development')
# Pandas(Index=319, code='2', name='Public sector governance')
# Pandas(Index=320, code='9', name='Urban development')
# Pandas(Index=321, code='6', name='Social protection and risk management')
# Pandas(Index=322, code='6', name='Social protection and risk management')
# Pandas(Index=323, code='8', name='Human development')
# Pandas(Index=324, code='8', name='Human development')
# Pandas(Index=325, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=326, code='6', name='Social protection and risk management')
# Pandas(Index=327, code='6', name='Social protection and risk management')
# Pandas(Index=328, code='6', name='Social protection and risk management')
# Pandas(Index=329, code='6', name='Social protection and risk management')
# Pandas(Index=330, code='6', name='Social protection and risk management')
# Pandas(Index=331, code='4', name='Financial and private sector development')
# Pandas(Index=332, code='2', name='')
# Pandas(Index=333, code='9', name='')
# Pandas(Index=334, code='6', name='Social protection and risk management')
# Pandas(Index=335, code='10', name='Rural development')
# Pandas(Index=336, code='10', name='Rural development')
# Pandas(Index=337, code='10', name='Rural development')
# Pandas(Index=338, code='11', name='Environment and natural resources management')
# Pandas(Index=339, code='2', name='Public sector governance')
# Pandas(Index=340, code='2', name='Public sector governance')
# Pandas(Index=341, code='9', name='Urban development')
# Pandas(Index=342, code='6', name='Social protection and risk management')
# Pandas(Index=343, code='11', name='Environment and natural resources management')
# Pandas(Index=344, code='10', name='Rural development')
# Pandas(Index=345, code='2', name='Public sector governance')
# Pandas(Index=346, code='2', name='Public sector governance')
# Pandas(Index=347, code='6', name='Social protection and risk management')
# Pandas(Index=348, code='10', name='Rural development')
# Pandas(Index=349, code='2', name='Public sector governance')
# Pandas(Index=350, code='2', name='Public sector governance')
# Pandas(Index=351, code='2', name='Public sector governance')
# Pandas(Index=352, code='2', name='Public sector governance')
# Pandas(Index=353, code='10', name='Rural development')
# Pandas(Index=354, code='9', name='Urban development')
# Pandas(Index=355, code='2', name='Public sector governance')
# Pandas(Index=356, code='9', name='Urban development')
# Pandas(Index=357, code='1', name='Economic management')
# Pandas(Index=358, code='2', name='Public sector governance')
# Pandas(Index=359, code='3', name='Rule of law')
# Pandas(Index=360, code='6', name='Social protection and risk management')
# Pandas(Index=361, code='6', name='Social protection and risk management')
# Pandas(Index=362, code='4', name='Financial and private sector development')
# Pandas(Index=363, code='1', name='')
# Pandas(Index=364, code='4', name='Financial and private sector development')
# Pandas(Index=365, code='7', name='')
# Pandas(Index=366, code='6', name='Social protection and risk management')
# Pandas(Index=367, code='2', name='Public sector governance')
# Pandas(Index=368, code='11', name='Environment and natural resources management')
# Pandas(Index=369, code='9', name='Urban development')
# Pandas(Index=370, code='2', name='Public sector governance')
# Pandas(Index=371, code='8', name='Human development')
# Pandas(Index=372, code='2', name='Public sector governance')
# Pandas(Index=373, code='8', name='Human development')
# Pandas(Index=374, code='11', name='Environment and natural resources management')
# Pandas(Index=375, code='11', name='Environment and natural resources management')
# Pandas(Index=376, code='5', name='Trade and integration')
# Pandas(Index=377, code='11', name='Environment and natural resources management')
# Pandas(Index=378, code='4', name='Financial and private sector development')
# Pandas(Index=379, code='6', name='Social protection and risk management')
# Pandas(Index=380, code='2', name='Public sector governance')
# Pandas(Index=381, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=382, code='2', name='Public sector governance')
# Pandas(Index=383, code='2', name='Public sector governance')
# Pandas(Index=384, code='6', name='Social protection and risk management')
# Pandas(Index=385, code='6', name='Social protection and risk management')
# Pandas(Index=386, code='8', name='Human development')
# Pandas(Index=387, code='8', name='Human development')
# Pandas(Index=388, code='2', name='Public sector governance')
# Pandas(Index=389, code='11', name='')
# Pandas(Index=390, code='4', name='Financial and private sector development')
# Pandas(Index=391, code='10', name='')
# Pandas(Index=392, code='10', name='Rural development')
# Pandas(Index=393, code='5', name='Trade and integration')
# Pandas(Index=394, code='4', name='Financial and private sector development')
# Pandas(Index=395, code='4', name='Financial and private sector development')
# Pandas(Index=396, code='5', name='Trade and integration')
# Pandas(Index=397, code='5', name='Trade and integration')
# Pandas(Index=398, code='4', name='Financial and private sector development')
# Pandas(Index=399, code='4', name='Financial and private sector development')
# Pandas(Index=400, code='2', name='Public sector governance')
# Pandas(Index=401, code='6', name='Social protection and risk management')
# Pandas(Index=402, code='10', name='Rural development')
# Pandas(Index=403, code='11', name='Environment and natural resources management')
# Pandas(Index=404, code='2', name='Public sector governance')
# Pandas(Index=405, code='4', name='')
# Pandas(Index=406, code='4', name='Financial and private sector development')
# Pandas(Index=407, code='11', name='')
# Pandas(Index=408, code='11', name='Environment and natural resources management')
# Pandas(Index=409, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=410, code='11', name='Environment and natural resources management')
# Pandas(Index=411, code='11', name='Environment and natural resources management')
# Pandas(Index=412, code='11', name='Environment and natural resources management')
# Pandas(Index=413, code='8', name='Human development')
# Pandas(Index=414, code='9', name='Urban development')
# Pandas(Index=415, code='3', name='Rule of law')
# Pandas(Index=416, code='5', name='Trade and integration')
# Pandas(Index=417, code='4', name='Financial and private sector development')
# Pandas(Index=418, code='6', name='Social protection and risk management')
# Pandas(Index=419, code='11', name='Environment and natural resources management')
# Pandas(Index=420, code='2', name='Public sector governance')
# Pandas(Index=421, code='11', name='Environment and natural resources management')
# Pandas(Index=422, code='11', name='Environment and natural resources management')
# Pandas(Index=423, code='11', name='Environment and natural resources management')
# Pandas(Index=424, code='10', name='')
# Pandas(Index=425, code='4', name='Financial and private sector development')
# Pandas(Index=426, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=427, code='4', name='Financial and private sector development')
# Pandas(Index=428, code='6', name='Social protection and risk management')
# Pandas(Index=429, code='6', name='Social protection and risk management')
# Pandas(Index=430, code='6', name='Social protection and risk management')
# Pandas(Index=431, code='2', name='Public sector governance')
# Pandas(Index=432, code='11', name='Environment and natural resources management')
# Pandas(Index=433, code='8', name='')
# Pandas(Index=434, code='11', name='Environment and natural resources management')
# Pandas(Index=435, code='10', name='')
# Pandas(Index=436, code='6', name='Social protection and risk management')
# Pandas(Index=437, code='10', name='Rural development')
# Pandas(Index=438, code='10', name='Rural development')
# Pandas(Index=439, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=440, code='10', name='Rural development')
# Pandas(Index=441, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=442, code='4', name='Financial and private sector development')
# Pandas(Index=443, code='11', name='Environment and natural resources management')
# Pandas(Index=444, code='10', name='Rural development')
# Pandas(Index=445, code='11', name='Environment and natural resources management')
# Pandas(Index=446, code='11', name='')
# Pandas(Index=447, code='9', name='Urban development')
# Pandas(Index=448, code='4', name='Financial and private sector development')
# Pandas(Index=449, code='11', name='Environment and natural resources management')
# Pandas(Index=450, code='6', name='Social protection and risk management')
# Pandas(Index=451, code='2', name='Public sector governance')
# Pandas(Index=452, code='4', name='Financial and private sector development')
# Pandas(Index=453, code='1', name='Economic management')
# Pandas(Index=454, code='1', name='Economic management')
# Pandas(Index=455, code='4', name='Financial and private sector development')
# Pandas(Index=456, code='2', name='Public sector governance')
# Pandas(Index=457, code='10', name='Rural development')
# Pandas(Index=458, code='1', name='Economic management')
# Pandas(Index=459, code='8', name='Human development')
# Pandas(Index=460, code='9', name='')
# Pandas(Index=461, code='8', name='Human development')
# Pandas(Index=462, code='2', name='')
# Pandas(Index=463, code='11', name='Environment and natural resources management')
# Pandas(Index=464, code='11', name='Environment and natural resources management')
# Pandas(Index=465, code='8', name='Human development')
# Pandas(Index=466, code='8', name='Human development')
# Pandas(Index=467, code='8', name='Human development')
# Pandas(Index=468, code='8', name='Human development')
# Pandas(Index=469, code='8', name='Human development')
# Pandas(Index=470, code='11', name='Environment and natural resources management')
# Pandas(Index=471, code='9', name='')
# Pandas(Index=472, code='11', name='Environment and natural resources management')
# Pandas(Index=473, code='11', name='Environment and natural resources management')
# Pandas(Index=474, code='11', name='Environment and natural resources management')
# Pandas(Index=475, code='2', name='Public sector governance')
# Pandas(Index=476, code='11', name='Environment and natural resources management')
# Pandas(Index=477, code='11', name='Environment and natural resources management')
# Pandas(Index=478, code='10', name='Rural development')
# Pandas(Index=479, code='10', name='Rural development')
# Pandas(Index=480, code='5', name='Trade and integration')
# Pandas(Index=481, code='4', name='Financial and private sector development')
# Pandas(Index=482, code='4', name='Financial and private sector development')
# Pandas(Index=483, code='5', name='Trade and integration')
# Pandas(Index=484, code='8', name='Human development')
# Pandas(Index=485, code='8', name='Human development')
# Pandas(Index=486, code='2', name='')
# Pandas(Index=487, code='5', name='Trade and integration')
# Pandas(Index=488, code='4', name='Financial and private sector development')
# Pandas(Index=489, code='2', name='Public sector governance')
# Pandas(Index=490, code='8', name='Human development')
# Pandas(Index=491, code='2', name='Public sector governance')
# Pandas(Index=492, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=493, code='3', name='')
# Pandas(Index=494, code='4', name='Financial and private sector development')
# Pandas(Index=495, code='6', name='Social protection and risk management')
# Pandas(Index=496, code='2', name='Public sector governance')
# Pandas(Index=497, code='1', name='Economic management')
# Pandas(Index=498, code='5', name='Trade and integration')
# Pandas(Index=499, code='6', name='Social protection and risk management')
# Pandas(Index=500, code='2', name='Public sector governance')
# Pandas(Index=501, code='2', name='Public sector governance')
# Pandas(Index=502, code='2', name='Public sector governance')
# Pandas(Index=503, code='11', name='Environment and natural resources management')
# Pandas(Index=504, code='11', name='Environment and natural resources management')
# Pandas(Index=505, code='10', name='Rural development')
# Pandas(Index=506, code='10', name='Rural development')
# Pandas(Index=507, code='2', name='Public sector governance')
# Pandas(Index=508, code='3', name='Rule of law')
# Pandas(Index=509, code='3', name='Rule of law')
# Pandas(Index=510, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=511, code='11', name='Environment and natural resources management')
# Pandas(Index=512, code='9', name='Urban development')
# Pandas(Index=513, code='9', name='Urban development')
# Pandas(Index=514, code='8', name='Human development')
# Pandas(Index=515, code='6', name='Social protection and risk management')
# Pandas(Index=516, code='2', name='Public sector governance')
# Pandas(Index=517, code='2', name='Public sector governance')
# Pandas(Index=518, code='2', name='Public sector governance')
# Pandas(Index=519, code='11', name='Environment and natural resources management')
# Pandas(Index=520, code='11', name='Environment and natural resources management')
# Pandas(Index=521, code='11', name='Environment and natural resources management')
# Pandas(Index=522, code='10', name='Rural development')
# Pandas(Index=523, code='11', name='Environment and natural resources management')
# Pandas(Index=524, code='6', name='Social protection and risk management')
# Pandas(Index=525, code='8', name='Human development')
# Pandas(Index=526, code='10', name='Rural development')
# Pandas(Index=527, code='10', name='Rural development')
# Pandas(Index=528, code='11', name='Environment and natural resources management')
# Pandas(Index=529, code='4', name='Financial and private sector development')
# Pandas(Index=530, code='11', name='Environment and natural resources management')
# Pandas(Index=531, code='10', name='Rural development')
# Pandas(Index=532, code='4', name='')
# Pandas(Index=533, code='5', name='Trade and integration')
# Pandas(Index=534, code='5', name='Trade and integration')
# Pandas(Index=535, code='9', name='Urban development')
# Pandas(Index=536, code='8', name='Human development')
# Pandas(Index=537, code='6', name='Social protection and risk management')
# Pandas(Index=538, code='8', name='Human development')
# Pandas(Index=539, code='6', name='Social protection and risk management')
# Pandas(Index=540, code='8', name='Human development')
# Pandas(Index=541, code='8', name='Human development')
# Pandas(Index=542, code='6', name='Social protection and risk management')
# Pandas(Index=543, code='4', name='Financial and private sector development')
# Pandas(Index=544, code='4', name='Financial and private sector development')
# Pandas(Index=545, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=546, code='2', name='Public sector governance')
# Pandas(Index=547, code='8', name='Human development')
# Pandas(Index=548, code='10', name='Rural development')
# Pandas(Index=549, code='8', name='Human development')
# Pandas(Index=550, code='6', name='Social protection and risk management')
# Pandas(Index=551, code='8', name='Human development')
# Pandas(Index=552, code='6', name='Social protection and risk management')
# Pandas(Index=553, code='6', name='Social protection and risk management')
# Pandas(Index=554, code='6', name='Social protection and risk management')
# Pandas(Index=555, code='6', name='Social protection and risk management')
# Pandas(Index=556, code='2', name='Public sector governance')
# Pandas(Index=557, code='2', name='Public sector governance')
# Pandas(Index=558, code='2', name='Public sector governance')
# Pandas(Index=559, code='4', name='Financial and private sector development')
# Pandas(Index=560, code='5', name='Trade and integration')
# Pandas(Index=561, code='8', name='Human development')
# Pandas(Index=562, code='11', name='')
# Pandas(Index=563, code='11', name='Environment and natural resources management')
# Pandas(Index=564, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=565, code='11', name='Environment and natural resources management')
# Pandas(Index=566, code='11', name='Environment and natural resources management')
# Pandas(Index=567, code='11', name='Environment and natural resources management')
# Pandas(Index=568, code='11', name='Environment and natural resources management')
# Pandas(Index=569, code='11', name='Environment and natural resources management')
# Pandas(Index=570, code='9', name='Urban development')
# Pandas(Index=571, code='2', name='Public sector governance')
# Pandas(Index=572, code='4', name='Financial and private sector development')
# Pandas(Index=573, code='10', name='Rural development')
# Pandas(Index=574, code='8', name='Human development')
# Pandas(Index=575, code='8', name='Human development')
# Pandas(Index=576, code='8', name='Human development')
# Pandas(Index=577, code='2', name='Public sector governance')
# Pandas(Index=578, code='2', name='Public sector governance')
# Pandas(Index=579, code='2', name='Public sector governance')
# Pandas(Index=580, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=581, code='2', name='Public sector governance')
# Pandas(Index=582, code='4', name='Financial and private sector development')
# Pandas(Index=583, code='5', name='Trade and integration')
# Pandas(Index=584, code='5', name='Trade and integration')
# Pandas(Index=585, code='9', name='Urban development')
# Pandas(Index=586, code='11', name='Environment and natural resources management')
# Pandas(Index=587, code='11', name='Environment and natural resources management')
# Pandas(Index=588, code='11', name='Environment and natural resources management')
# Pandas(Index=589, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=590, code='2', name='')
# Pandas(Index=591, code='2', name='Public sector governance')
# Pandas(Index=592, code='2', name='Public sector governance')
# Pandas(Index=593, code='2', name='Public sector governance')
# Pandas(Index=594, code='11', name='Environment and natural resources management')
# Pandas(Index=595, code='6', name='Social protection and risk management')
# Pandas(Index=596, code='6', name='Social protection and risk management')
# Pandas(Index=597, code='9', name='Urban development')
# Pandas(Index=598, code='9', name='Urban development')
# Pandas(Index=599, code='5', name='Trade and integration')
# Pandas(Index=600, code='2', name='Public sector governance')
# Pandas(Index=601, code='5', name='Trade and integration')
# Pandas(Index=602, code='10', name='Rural development')
# Pandas(Index=603, code='11', name='Environment and natural resources management')
# Pandas(Index=604, code='4', name='Financial and private sector development')
# Pandas(Index=605, code='4', name='Financial and private sector development')
# Pandas(Index=606, code='5', name='Trade and integration')
# Pandas(Index=607, code='2', name='Public sector governance')
# Pandas(Index=608, code='2', name='Public sector governance')
# Pandas(Index=609, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=610, code='2', name='Public sector governance')
# Pandas(Index=611, code='6', name='')
# Pandas(Index=612, code='8', name='Human development')
# Pandas(Index=613, code='8', name='Human development')
# Pandas(Index=614, code='8', name='Human development')
# Pandas(Index=615, code='8', name='Human development')
# Pandas(Index=616, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=617, code='6', name='Social protection and risk management')
# Pandas(Index=618, code='8', name='Human development')
# Pandas(Index=619, code='6', name='Social protection and risk management')
# Pandas(Index=620, code='8', name='Human development')
# Pandas(Index=621, code='8', name='Human development')
# Pandas(Index=622, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=623, code='10', name='Rural development')
# Pandas(Index=624, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=625, code='8', name='Human development')
# Pandas(Index=626, code='8', name='Human development')
# Pandas(Index=627, code='8', name='Human development')
# Pandas(Index=628, code='6', name='Social protection and risk management')
# Pandas(Index=629, code='8', name='Human development')
# Pandas(Index=630, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=631, code='11', name='Environment and natural resources management')
# Pandas(Index=632, code='11', name='Environment and natural resources management')
# Pandas(Index=633, code='11', name='Environment and natural resources management')
# Pandas(Index=634, code='5', name='Trade and integration')
# Pandas(Index=635, code='11', name='Environment and natural resources management')
# Pandas(Index=636, code='6', name='Social protection and risk management')
# Pandas(Index=637, code='8', name='Human development')
# Pandas(Index=638, code='8', name='Human development')
# Pandas(Index=639, code='6', name='Social protection and risk management')
# Pandas(Index=640, code='8', name='Human development')
# Pandas(Index=641, code='8', name='Human development')
# Pandas(Index=642, code='5', name='Trade and integration')
# Pandas(Index=643, code='2', name='Public sector governance')
# Pandas(Index=644, code='6', name='Social protection and risk management')
# Pandas(Index=645, code='2', name='Public sector governance')
# Pandas(Index=646, code='10', name='Rural development')
# Pandas(Index=647, code='1', name='Economic management')
# Pandas(Index=648, code='1', name='Economic management')
# Pandas(Index=649, code='2', name='Public sector governance')
# Pandas(Index=650, code='9', name='Urban development')
# Pandas(Index=651, code='11', name='Environment and natural resources management')
# Pandas(Index=652, code='11', name='Environment and natural resources management')
# Pandas(Index=653, code='4', name='Financial and private sector development')
# Pandas(Index=654, code='5', name='Trade and integration')
# Pandas(Index=655, code='11', name='Environment and natural resources management')
# Pandas(Index=656, code='11', name='Environment and natural resources management')
# Pandas(Index=657, code='5', name='Trade and integration')
# Pandas(Index=658, code='4', name='Financial and private sector development')
# Pandas(Index=659, code='2', name='Public sector governance')
# Pandas(Index=660, code='2', name='Public sector governance')
# Pandas(Index=661, code='2', name='Public sector governance')
# Pandas(Index=662, code='11', name='Environment and natural resources management')
# Pandas(Index=663, code='10', name='')
# Pandas(Index=664, code='11', name='Environment and natural resources management')
# Pandas(Index=665, code='2', name='Public sector governance')
# Pandas(Index=666, code='10', name='Rural development')
# Pandas(Index=667, code='11', name='Environment and natural resources management')
# Pandas(Index=668, code='11', name='Environment and natural resources management')
# Pandas(Index=669, code='9', name='Urban development')
# Pandas(Index=670, code='4', name='Financial and private sector development')
# Pandas(Index=671, code='4', name='Financial and private sector development')
# Pandas(Index=672, code='10', name='Rural development')
# Pandas(Index=673, code='10', name='Rural development')
# Pandas(Index=674, code='4', name='Financial and private sector development')
# Pandas(Index=675, code='10', name='Rural development')
# Pandas(Index=676, code='11', name='Environment and natural resources management')
# Pandas(Index=677, code='6', name='Social protection and risk management')
# Pandas(Index=678, code='2', name='')
# Pandas(Index=679, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=680, code='8', name='')
# Pandas(Index=681, code='8', name='Human development')
# Pandas(Index=682, code='11', name='')
# Pandas(Index=683, code='11', name='Environment and natural resources management')
# Pandas(Index=684, code='7', name='')
# Pandas(Index=685, code='11', name='Environment and natural resources management')
# Pandas(Index=686, code='11', name='')
# Pandas(Index=687, code='8', name='Human development')
# Pandas(Index=688, code='8', name='Human development')
# Pandas(Index=689, code='8', name='Human development')
# Pandas(Index=690, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=691, code='3', name='')
# Pandas(Index=692, code='10', name='Rural development')
# Pandas(Index=693, code='8', name='Human development')
# Pandas(Index=694, code='11', name='Environment and natural resources management')
# Pandas(Index=695, code='10', name='')
# Pandas(Index=696, code='8', name='Human development')
# Pandas(Index=697, code='8', name='Human development')
# Pandas(Index=698, code='8', name='Human development')
# Pandas(Index=699, code='8', name='Human development')
# Pandas(Index=700, code='8', name='Human development')
# Pandas(Index=701, code='11', name='')
# Pandas(Index=702, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=703, code='8', name='Human development')
# Pandas(Index=704, code='10', name='Rural development')
# Pandas(Index=705, code='4', name='Financial and private sector development')
# Pandas(Index=706, code='2', name='Public sector governance')
# Pandas(Index=707, code='2', name='Public sector governance')
# Pandas(Index=708, code='10', name='Rural development')
# Pandas(Index=709, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=710, code='10', name='Rural development')
# Pandas(Index=711, code='8', name='Human development')
# Pandas(Index=712, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=713, code='8', name='Human development')
# Pandas(Index=714, code='8', name='Human development')
# Pandas(Index=715, code='8', name='Human development')
# Pandas(Index=716, code='8', name='Human development')
# Pandas(Index=717, code='8', name='Human development')
# Pandas(Index=718, code='6', name='Social protection and risk management')
# Pandas(Index=719, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=720, code='8', name='Human development')
# Pandas(Index=721, code='6', name='Social protection and risk management')
# Pandas(Index=722, code='8', name='Human development')
# Pandas(Index=723, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=724, code='10', name='Rural development')
# Pandas(Index=725, code='11', name='Environment and natural resources management')
# Pandas(Index=726, code='11', name='Environment and natural resources management')
# Pandas(Index=727, code='10', name='Rural development')
# Pandas(Index=728, code='10', name='Rural development')
# Pandas(Index=729, code='11', name='Environment and natural resources management')
# Pandas(Index=730, code='10', name='Rural development')
# Pandas(Index=731, code='10', name='Rural development')
# Pandas(Index=732, code='9', name='Urban development')
# Pandas(Index=733, code='11', name='Environment and natural resources management')
# Pandas(Index=734, code='11', name='Environment and natural resources management')
# Pandas(Index=735, code='8', name='Human development')
# Pandas(Index=736, code='8', name='Human development')
# Pandas(Index=737, code='9', name='Urban development')
# Pandas(Index=738, code='9', name='Urban development')
# Pandas(Index=739, code='9', name='Urban development')
# Pandas(Index=740, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=741, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=742, code='9', name='Urban development')
# Pandas(Index=743, code='6', name='Social protection and risk management')
# Pandas(Index=744, code='10', name='Rural development')
# Pandas(Index=745, code='6', name='Social protection and risk management')
# Pandas(Index=746, code='2', name='Public sector governance')
# Pandas(Index=747, code='10', name='Rural development')
# Pandas(Index=748, code='11', name='Environment and natural resources management')
# Pandas(Index=749, code='10', name='Rural development')
# Pandas(Index=750, code='10', name='Rural development')
# Pandas(Index=751, code='10', name='Rural development')
# Pandas(Index=752, code='10', name='Rural development')
# Pandas(Index=753, code='10', name='Rural development')
# Pandas(Index=754, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=755, code='10', name='Rural development')
# Pandas(Index=756, code='10', name='Rural development')
# Pandas(Index=757, code='6', name='Social protection and risk management')
# Pandas(Index=758, code='8', name='Human development')
# Pandas(Index=759, code='8', name='Human development')
# Pandas(Index=760, code='8', name='Human development')
# Pandas(Index=761, code='8', name='Human development')
# ...
# Pandas(Index=1247, code='8', name='Human development')
# Pandas(Index=1248, code='8', name='Human development')
# Pandas(Index=1249, code='10', name='Rural development')
# Pandas(Index=1250, code='10', name='Rural development')
# Pandas(Index=1251, code='10', name='Rural development')
# Pandas(Index=1252, code='6', name='Social protection and risk management')
# Pandas(Index=1253, code='4', name='Financial and private sector development')
# Pandas(Index=1254, code='8', name='Human development')
# Pandas(Index=1255, code='8', name='Human development')
# Pandas(Index=1256, code='6', name='Social protection and risk management')
# Pandas(Index=1257, code='1', name='Economic management')
# Pandas(Index=1258, code='8', name='')
# Pandas(Index=1259, code='6', name='Social protection and risk management')
# Pandas(Index=1260, code='1', name='Economic management')
# Pandas(Index=1261, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=1262, code='8', name='Human development')
# Pandas(Index=1263, code='4', name='Financial and private sector development')
# Pandas(Index=1264, code='10', name='Rural development')
# Pandas(Index=1265, code='5', name='Trade and integration')
# Pandas(Index=1266, code='5', name='Trade and integration')
# Pandas(Index=1267, code='10', name='Rural development')
# Pandas(Index=1268, code='2', name='')
# Pandas(Index=1269, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=1270, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=1271, code='10', name='Rural development')
# Pandas(Index=1272, code='8', name='Human development')
# Pandas(Index=1273, code='10', name='Rural development')
# Pandas(Index=1274, code='2', name='Public sector governance')
# Pandas(Index=1275, code='2', name='Public sector governance')
# Pandas(Index=1276, code='4', name='Financial and private sector development')
# Pandas(Index=1277, code='4', name='')
# Pandas(Index=1278, code='8', name='Human development')
# Pandas(Index=1279, code='4', name='Financial and private sector development')
# Pandas(Index=1280, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=1281, code='2', name='Public sector governance')
# Pandas(Index=1282, code='2', name='Public sector governance')
# Pandas(Index=1283, code='11', name='Environment and natural resources management')
# Pandas(Index=1284, code='11', name='Environment and natural resources management')
# Pandas(Index=1285, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=1286, code='11', name='Environment and natural resources management')
# Pandas(Index=1287, code='3', name='Rule of law')
# Pandas(Index=1288, code='4', name='Financial and private sector development')
# Pandas(Index=1289, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=1290, code='9', name='Urban development')
# Pandas(Index=1291, code='2', name='Public sector governance')
# Pandas(Index=1292, code='4', name='Financial and private sector development')
# Pandas(Index=1293, code='2', name='Public sector governance')
# Pandas(Index=1294, code='4', name='Financial and private sector development')
# Pandas(Index=1295, code='2', name='Public sector governance')
# Pandas(Index=1296, code='10', name='Rural development')
# Pandas(Index=1297, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=1298, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=1299, code='10', name='Rural development')
# Pandas(Index=1300, code='10', name='Rural development')
# Pandas(Index=1301, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=1302, code='3', name='Rule of law')
# Pandas(Index=1303, code='9', name='Urban development')
# Pandas(Index=1304, code='8', name='Human development')
# Pandas(Index=1305, code='8', name='Human development')
# Pandas(Index=1306, code='8', name='Human development')
# Pandas(Index=1307, code='8', name='Human development')
# Pandas(Index=1308, code='8', name='Human development')
# Pandas(Index=1309, code='10', name='Rural development')
# Pandas(Index=1310, code='10', name='Rural development')
# Pandas(Index=1311, code='10', name='Rural development')
# Pandas(Index=1312, code='4', name='Financial and private sector development')
# Pandas(Index=1313, code='8', name='Human development')
# Pandas(Index=1314, code='10', name='Rural development')
# Pandas(Index=1315, code='10', name='Rural development')
# Pandas(Index=1316, code='3', name='Rule of law')
# Pandas(Index=1317, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=1318, code='9', name='Urban development')
# Pandas(Index=1319, code='5', name='')
# Pandas(Index=1320, code='8', name='Human development')
# Pandas(Index=1321, code='11', name='Environment and natural resources management')
# Pandas(Index=1322, code='8', name='Human development')
# Pandas(Index=1323, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=1324, code='11', name='Environment and natural resources management')
# Pandas(Index=1325, code='11', name='Environment and natural resources management')
# Pandas(Index=1326, code='8', name='Human development')
# Pandas(Index=1327, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=1328, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=1329, code='4', name='')
# Pandas(Index=1330, code='8', name='Human development')
# Pandas(Index=1331, code='11', name='')
# Pandas(Index=1332, code='10', name='Rural development')
# Pandas(Index=1333, code='10', name='Rural development')
# Pandas(Index=1334, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=1335, code='10', name='Rural development')
# Pandas(Index=1336, code='10', name='Rural development')
# Pandas(Index=1337, code='4', name='Financial and private sector development')
# Pandas(Index=1338, code='2', name='Public sector governance')
# Pandas(Index=1339, code='4', name='Financial and private sector development')
# Pandas(Index=1340, code='6', name='Social protection and risk management')
# Pandas(Index=1341, code='6', name='Social protection and risk management')
# Pandas(Index=1342, code='9', name='Urban development')
# Pandas(Index=1343, code='11', name='Environment and natural resources management')
# Pandas(Index=1344, code='10', name='Rural development')
# Pandas(Index=1345, code='5', name='Trade and integration')
# Pandas(Index=1346, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=1347, code='9', name='Urban development')
# Pandas(Index=1348, code='8', name='Human development')
# Pandas(Index=1349, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=1350, code='8', name='Human development')
# Pandas(Index=1351, code='2', name='')
# Pandas(Index=1352, code='10', name='Rural development')
# Pandas(Index=1353, code='2', name='Public sector governance')
# Pandas(Index=1354, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=1355, code='8', name='Human development')
# Pandas(Index=1356, code='2', name='Public sector governance')
# Pandas(Index=1357, code='8', name='Human development')
# Pandas(Index=1358, code='2', name='')
# Pandas(Index=1359, code='8', name='Human development')
# Pandas(Index=1360, code='11', name='')
# Pandas(Index=1361, code='6', name='Social protection and risk management')
# Pandas(Index=1362, code='4', name='Financial and private sector development')
# Pandas(Index=1363, code='11', name='Environment and natural resources management')
# Pandas(Index=1364, code='10', name='Rural development')
# Pandas(Index=1365, code='6', name='Social protection and risk management')
# Pandas(Index=1366, code='8', name='Human development')
# Pandas(Index=1367, code='8', name='Human development')
# Pandas(Index=1368, code='8', name='Human development')
# Pandas(Index=1369, code='10', name='Rural development')
# Pandas(Index=1370, code='2', name='Public sector governance')
# Pandas(Index=1371, code='6', name='Social protection and risk management')
# Pandas(Index=1372, code='5', name='Trade and integration')
# Pandas(Index=1373, code='10', name='Rural development')
# Pandas(Index=1374, code='10', name='Rural development')
# Pandas(Index=1375, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=1376, code='11', name='Environment and natural resources management')
# Pandas(Index=1377, code='8', name='Human development')
# Pandas(Index=1378, code='2', name='Public sector governance')
# Pandas(Index=1379, code='2', name='Public sector governance')
# Pandas(Index=1380, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=1381, code='8', name='Human development')
# Pandas(Index=1382, code='5', name='Trade and integration')
# Pandas(Index=1383, code='10', name='Rural development')
# Pandas(Index=1384, code='5', name='Trade and integration')
# Pandas(Index=1385, code='4', name='Financial and private sector development')
# Pandas(Index=1386, code='10', name='Rural development')
# Pandas(Index=1387, code='11', name='Environment and natural resources management')
# Pandas(Index=1388, code='2', name='Public sector governance')
# Pandas(Index=1389, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=1390, code='11', name='Environment and natural resources management')
# Pandas(Index=1391, code='2', name='Public sector governance')
# Pandas(Index=1392, code='6', name='Social protection and risk management')
# Pandas(Index=1393, code='10', name='Rural development')
# Pandas(Index=1394, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=1395, code='2', name='Public sector governance')
# Pandas(Index=1396, code='5', name='Trade and integration')
# Pandas(Index=1397, code='8', name='Human development')
# Pandas(Index=1398, code='6', name='Social protection and risk management')
# Pandas(Index=1399, code='10', name='Rural development')
# Pandas(Index=1400, code='10', name='Rural development')
# Pandas(Index=1401, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=1402, code='11', name='Environment and natural resources management')
# Pandas(Index=1403, code='6', name='Social protection and risk management')
# Pandas(Index=1404, code='11', name='Environment and natural resources management')
# Pandas(Index=1405, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=1406, code='2', name='Public sector governance')
# Pandas(Index=1407, code='2', name='Public sector governance')
# Pandas(Index=1408, code='4', name='Financial and private sector development')
# Pandas(Index=1409, code='2', name='Public sector governance')
# Pandas(Index=1410, code='6', name='Social protection and risk management')
# Pandas(Index=1411, code='3', name='Rule of law')
# Pandas(Index=1412, code='5', name='Trade and integration')
# Pandas(Index=1413, code='4', name='Financial and private sector development')
# Pandas(Index=1414, code='11', name='')
# Pandas(Index=1415, code='5', name='Trade and integration')
# Pandas(Index=1416, code='10', name='Rural development')
# Pandas(Index=1417, code='10', name='Rural development')
# Pandas(Index=1418, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=1419, code='11', name='Environment and natural resources management')
# Pandas(Index=1420, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=1421, code='11', name='Environment and natural resources management')
# Pandas(Index=1422, code='11', name='')
# Pandas(Index=1423, code='11', name='Environment and natural resources management')
# Pandas(Index=1424, code='4', name='')
# Pandas(Index=1425, code='9', name='Urban development')
# Pandas(Index=1426, code='9', name='Urban development')
# Pandas(Index=1427, code='4', name='Financial and private sector development')
# Pandas(Index=1428, code='9', name='Urban development')
# Pandas(Index=1429, code='10', name='Rural development')
# Pandas(Index=1430, code='8', name='')
# Pandas(Index=1431, code='4', name='Financial and private sector development')
# Pandas(Index=1432, code='10', name='Rural development')
# Pandas(Index=1433, code='2', name='Public sector governance')
# Pandas(Index=1434, code='3', name='Rule of law')
# Pandas(Index=1435, code='11', name='Environment and natural resources management')
# Pandas(Index=1436, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=1437, code='1', name='')
# Pandas(Index=1438, code='2', name='Public sector governance')
# Pandas(Index=1439, code='11', name='')
# Pandas(Index=1440, code='8', name='Human development')
# Pandas(Index=1441, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=1442, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=1443, code='8', name='Human development')
# Pandas(Index=1444, code='10', name='Rural development')
# Pandas(Index=1445, code='11', name='Environment and natural resources management')
# Pandas(Index=1446, code='11', name='Environment and natural resources management')
# Pandas(Index=1447, code='10', name='Rural development')
# Pandas(Index=1448, code='11', name='Environment and natural resources management')
# Pandas(Index=1449, code='11', name='Environment and natural resources management')
# Pandas(Index=1450, code='10', name='Rural development')
# Pandas(Index=1451, code='11', name='Environment and natural resources management')
# Pandas(Index=1452, code='10', name='Rural development')
# Pandas(Index=1453, code='4', name='Financial and private sector development')
# Pandas(Index=1454, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=1455, code='10', name='Rural development')
# Pandas(Index=1456, code='8', name='Human development')
# Pandas(Index=1457, code='4', name='')
# Pandas(Index=1458, code='2', name='Public sector governance')
# Pandas(Index=1459, code='6', name='Social protection and risk management')
# Pandas(Index=1460, code='6', name='Social protection and risk management')
# Pandas(Index=1461, code='6', name='Social protection and risk management')
# Pandas(Index=1462, code='11', name='Environment and natural resources management')
# Pandas(Index=1463, code='10', name='Rural development')
# Pandas(Index=1464, code='10', name='Rural development')
# Pandas(Index=1465, code='11', name='Environment and natural resources management')
# Pandas(Index=1466, code='8', name='Human development')
# Pandas(Index=1467, code='2', name='Public sector governance')
# Pandas(Index=1468, code='2', name='Public sector governance')
# Pandas(Index=1469, code='8', name='Human development')
# Pandas(Index=1470, code='9', name='Urban development')
# Pandas(Index=1471, code='6', name='Social protection and risk management')
# Pandas(Index=1472, code='6', name='Social protection and risk management')
# Pandas(Index=1473, code='9', name='Urban development')
# Pandas(Index=1474, code='2', name='Public sector governance')
# Pandas(Index=1475, code='2', name='Public sector governance')
# Pandas(Index=1476, code='10', name='Rural development')
# Pandas(Index=1477, code='11', name='')
# Pandas(Index=1478, code='8', name='Human development')
# Pandas(Index=1479, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=1480, code='11', name='Environment and natural resources management')
# Pandas(Index=1481, code='5', name='')
# Pandas(Index=1482, code='6', name='Social protection and risk management')
# Pandas(Index=1483, code='8', name='')
# Pandas(Index=1484, code='4', name='Financial and private sector development')
# Pandas(Index=1485, code='7', name='Social dev/gender/inclusion')
# Pandas(Index=1486, code='8', name='Human development')
# Pandas(Index=1487, code='5', name='Trade and integration')
# Pandas(Index=1488, code='2', name='Public sector governance')
# Pandas(Index=1489, code='8', name='Human development')
# Pandas(Index=1490, code='10', name='Rural development')
# Pandas(Index=1491, code='6', name='')
# Pandas(Index=1492, code='10', name='Rural development')
# Pandas(Index=1493, code='10', name='Rural development')
# Pandas(Index=1494, code='10', name='Rural development')
# Pandas(Index=1495, code='9', name='Urban development')
# Pandas(Index=1496, code='8', name='Human development')
# Pandas(Index=1497, code='5', name='Trade and integration')
# Pandas(Index=1498, code='4', name='Financial and private sector development')
# {'8': 'Human development', '1': 'Economic management', '6': 'Social protection and risk management', '5': 'Trade and integration', '2': 'Public sector governance', '11': 'Environment and natural resources management', '7': 'Social dev/gender/inclusion', '4': 'Financial and private sector development', '10': 'Rural development', '9': 'Urban development', '3': 'Rule of law'}

# %%
# fill in the missing names to orig df

for row in new_mjtheme.itertuples():
    if row[2] == '':
        new_mjtheme.set_value(row[0], 'name', code_names[row[1]])
        
#create dataframe to use value_counts() again
filled_mjtheme = pd.DataFrame(new_mjtheme)

filled_mjtheme_count = filled_mjtheme['name'].value_counts()
# Out:
# C:\Users\Tony\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   """

# %%
# 3. Create a dataframe with the missing names filled in.

print("--> 3. Top 10 major project themes with names filled in are: ")
print(filled_mjtheme_count.head(10))
# Out:
# --> 3. Top 10 major project themes with names filled in are:
# Environment and natural resources management    250
# Rural development                               216
# Human development                               210
# Public sector governance                        199
# Social protection and risk management           168
# Financial and private sector development        146
# Social dev/gender/inclusion                     130
# Trade and integration                            77
# Urban development                                50
# Economic management                              38
# Name: name, dtype: int64
